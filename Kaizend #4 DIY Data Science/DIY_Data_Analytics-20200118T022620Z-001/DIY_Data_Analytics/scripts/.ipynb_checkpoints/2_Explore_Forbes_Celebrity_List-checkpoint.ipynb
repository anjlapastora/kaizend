# %%
import pandas as pd
import numpy as np

# %%
fn = "../input/forbes_celebrity_list.csv"

# %%
df = pd.read_csv(fn)

# %%
# ?pd.read_csv

# %%
df # this is a pandas dataframe
# note that every row has an index and every column has a name
# Out:
#      year  rank              recipient                             country  \
# 0    1999     1         Michael Jordan                       United States
# 1    1999     2          Oprah Winfrey                       United States
# 2    1999     3      Leonardo DiCaprio                       United States
# 3    1999     4         Jerry Seinfeld                       United States
# 4    1999     5       Steven Spielberg                       United States
# 5    1999     6            Spice Girls                      United Kingdom
# 6    1999     7          Harrison Ford                       United States
# 7    1999     8         Robin Williams                       United States
# 8    1999     9            Celine Dion                              Canada
# 9    1999    10     The Rolling Stones                      United Kingdom
# 10   2000     1          Julia Roberts                       United States
# ...

# %%
df.head()
# Out:
#    year  rank          recipient        country                     career  \
# 0  1999     1     Michael Jordan  United States  Sportsperson (Basketball)
# 1  1999     2      Oprah Winfrey  United States     Television Personality
# 2  1999     3  Leonardo DiCaprio  United States                      Actor
# 3  1999     4     Jerry Seinfeld  United States                      Actor
# 4  1999     5   Steven Spielberg  United States                  Filmmaker
#
#    tied              title
# 0     0     Michael_Jordan
# 1     0      Oprah_Winfrey
# 2     0  Leonardo_DiCaprio
# 3     0     Jerry_Seinfeld
# 4     0   Steven_Spielberg

# %%
# inspect the first 10 rows
df.head(10)
# Out:
#    year  rank           recipient         country                     career  \
# 0  1999     1      Michael Jordan   United States  Sportsperson (Basketball)
# 1  1999     2       Oprah Winfrey   United States     Television Personality
# 2  1999     3   Leonardo DiCaprio   United States                      Actor
# 3  1999     4      Jerry Seinfeld   United States                      Actor
# 4  1999     5    Steven Spielberg   United States                  Filmmaker
# 5  1999     6         Spice Girls  United Kingdom                  Musicians
# 6  1999     7       Harrison Ford   United States                      Actor
# 7  1999     8      Robin Williams   United States                      Actor
# 8  1999     9         Celine Dion          Canada                   Musician
# 9  1999    10  The Rolling Stones  United Kingdom                  Musicians
#
#    tied               title
# 0     0      Michael_Jordan
# 1     0       Oprah_Winfrey
# 2     0   Leonardo_DiCaprio
# ...

# %%
# inspect the last 10 rows 
df.tail(10)
# Out:
#      year  rank              recipient              country  \
# 192  2018     1  Floyd Mayweather, Jr.        United States
# 193  2018     2         George Clooney        United States
# 194  2018     3           Kylie Jenner        United States
# 195  2018     4         Judy Sheindlin        United States
# 196  2018     5         Dwayne Johnson        United States
# 197  2018     6                     U2  Republic of Ireland
# 198  2018     7               Coldplay       United Kingdom
# 199  2018     8           Lionel Messi            Argentina
# 200  2018     9             Ed Sheeran       United Kingdom
# 201  2018    10      Cristiano Ronaldo             Portugal
#
#                              career  tied                 title
# 192                Athlete (Boxing)     0  Floyd_Mayweather_Jr.
# 193                           Actor     0        George_Clooney
# 194                     Personality     0          Kylie_Jenner
# ...

# %%
# count the number of rows
len(df)
# Out:
# 202

# %%
# get the column headers
df.columns
# Out:
# Index(['year', 'rank', 'recipient', 'country', 'career', 'tied', 'title'], dtype='object')

# %%
df[df["tied"]==1]
# Out:
#      year  rank   recipient        country                  career  tied  \
# 41   2003     2      Eminem  United States               Musicians     1
# 42   2003     2     Dr. Dre  United States               Musicians     1
# 100  2008    10   Brad Pitt  United States                   Actor     1
# 101  2008    10  Paula Deen  United States  Television Personality     1
#
#           title
# 41       Eminem
# 42      Dr._Dre
# 100   Brad_Pitt
# 101  Paula_Deen

# %%
# Access dataframe column, row, element
# Access specific column
df["recipient"]           # this is a pandas series
# Out:
# 0             Michael Jordan
# 1              Oprah Winfrey
# 2          Leonardo DiCaprio
# 3             Jerry Seinfeld
# 4           Steven Spielberg
# 5                Spice Girls
# 6              Harrison Ford
# 7             Robin Williams
# 8                Celine Dion
# 9         The Rolling Stones
# 10             Julia Roberts
# 11              George Lucas
# 12             Oprah Winfrey
# 13                 Tom Hanks
# 14            Michael Jordan
# 15        The Rolling Stones
# 16               Tiger Woods
# 17           Backstreet Boys
# 18                      Cher
# 19          Steven Spielberg
# 20                Tom Cruise
# 21               Tiger Woods
# 22               The Beatles
# 23            Britney Spears
# 24              Bruce Willis
# 25            Michael Jordan
# 26           Backstreet Boys
# 27                     NSYNC
# 28             Oprah Winfrey
# 29                Mel Gibson
#                ...
# 172             Taylor Swift
# ...

# %%
# show the first few values
df["recipient"].head(10)
# Out:
# 0        Michael Jordan
# 1         Oprah Winfrey
# 2     Leonardo DiCaprio
# 3        Jerry Seinfeld
# 4      Steven Spielberg
# 5           Spice Girls
# 6         Harrison Ford
# 7        Robin Williams
# 8           Celine Dion
# 9    The Rolling Stones
# Name: recipient, dtype: object

# %%
df.loc[[4,23,26]]
# Out:
#     year  rank         recipient        country     career  tied  \
# 4   1999     5  Steven Spielberg  United States  Filmmaker     0
# 23  2001     4    Britney Spears  United States   Musician     0
# 26  2001     7   Backstreet Boys  United States  Musicians     0
#
#                title
# 4   Steven_Spielberg
# 23    Britney_Spears
# 26   Backstreet_Boys

# %%
df.loc[0:4]
# Out:
#    year  rank          recipient        country                     career  \
# 0  1999     1     Michael Jordan  United States  Sportsperson (Basketball)
# 1  1999     2      Oprah Winfrey  United States     Television Personality
# 2  1999     3  Leonardo DiCaprio  United States                      Actor
# 3  1999     4     Jerry Seinfeld  United States                      Actor
# 4  1999     5   Steven Spielberg  United States                  Filmmaker
#
#    tied              title
# 0     0     Michael_Jordan
# 1     0      Oprah_Winfrey
# 2     0  Leonardo_DiCaprio
# 3     0     Jerry_Seinfeld
# 4     0   Steven_Spielberg

# %%
df.loc[4, "recipient"]
# Out:
# 'Steven Spielberg'

# %%
df[df["rank"]<=3]
# Out:
#      year  rank              recipient                             country  \
# 0    1999     1         Michael Jordan                       United States
# 1    1999     2          Oprah Winfrey                       United States
# 2    1999     3      Leonardo DiCaprio                       United States
# 10   2000     1          Julia Roberts                       United States
# 11   2000     2           George Lucas                       United States
# 12   2000     3          Oprah Winfrey                       United States
# 20   2001     1             Tom Cruise                       United States
# 21   2001     2            Tiger Woods                       United States
# 22   2001     3            The Beatles                      United Kingdom
# 30   2002     1         Britney Spears                       United States
# 31   2002     2            Tiger Woods                       United States
# ...

# %%
df[["recipient", "career", "rank"]].head()
# Out:
#            recipient                     career  rank
# 0     Michael Jordan  Sportsperson (Basketball)     1
# 1      Oprah Winfrey     Television Personality     2
# 2  Leonardo DiCaprio                      Actor     3
# 3     Jerry Seinfeld                      Actor     4
# 4   Steven Spielberg                  Filmmaker     5

# %%
# Tally values
df["career"].value_counts() # this is sorted from highest to lowest count
# Out:
# Musician                               52
# Actor                                  37
# Musicians                              26
# Television Personality                 23
# Filmmaker                              14
# Sportsperson (Golf)                    12
# Sportsperson (Basketball)              10
# Author                                  7
# Sportsperson (Association Football)     5
# Radio Personality                       4
# Sportsperson (Boxing)                   3
# Musician / Actor                        2
# Athlete (Association football)          2
# Personality                             2
# Actors                                  1
# Sportsperson (Tennis)                   1
# Athlete (Boxing)                        1
# Name: career, dtype: int64

# %%
# Filter by country
df[df["country"]=="Philippines"]
# Out:
#      year  rank       recipient      country                 career  tied  \
# 163  2015     2  Manny Pacquiao  Philippines  Sportsperson (Boxing)     0
#
#               title
# 163  Manny_Pacquiao

# %%
# Q: Who were in top 5 in the same year?
# Filter by rank and year
df[(df["rank"]<=5) & (df["year"]==2015)]
# Out:
#      year  rank              recipient                             country  \
# 162  2015     1  Floyd Mayweather, Jr.                       United States
# 163  2015     2         Manny Pacquiao                         Philippines
# 164  2015     3             Katy Perry                       United States
# 165  2015     4          One Direction  United Kingdom/Republic of Ireland
# 166  2015     5           Howard Stern                       United States
#
#                      career  tied                 title
# 162   Sportsperson (Boxing)     0  Floyd_Mayweather_Jr.
# 163   Sportsperson (Boxing)     0        Manny_Pacquiao
# 164                Musician     0            Katy_Perry
# 165               Musicians     0         One_Direction
# 166  Television Personality     0          Howard_Stern

# %%
# How many celerbrities are in the list?
recipients = pd.unique(df["recipient"])

# %%
len(recipients)
# Out:
# 82

# %%
recipients
# Out:
# array(['Michael Jordan', 'Oprah Winfrey', 'Leonardo DiCaprio',
#        'Jerry Seinfeld', 'Steven Spielberg', 'Spice Girls',
#        'Harrison Ford', 'Robin Williams', 'Celine Dion',
#        'The Rolling Stones', 'Julia Roberts', 'George Lucas', 'Tom Hanks',
#        'Tiger Woods', 'Backstreet Boys', 'Cher', 'Tom Cruise',
#        'The Beatles', 'Britney Spears', 'Bruce Willis', 'NSYNC',
#        'Mel Gibson', 'Madonna', 'U2', 'Mariah Carey', 'Jennifer Aniston',
#        'Eminem', 'Dr. Dre', 'Jennifer Lopez', 'Paul McCartney',
#        'Ben Affleck', 'J. K. Rowling', 'Bruce Springsteen', 'Johnny Depp',
#        "Shaquille O'Neal", 'Elton John', 'Howard Stern', '50 Cent',
#        'Cast of The Sopranos', 'Dan Brown', 'Brad Pitt', 'Jay-Z',
#        'Angelina Jolie', 'Beyonce', 'David Beckham', 'The Police',
#        'Paula Deen', 'Kobe Bryant', 'James Cameron', 'Lady Gaga',
#        'Sandra Bullock', 'Justin Bieber', 'Taylor Swift', 'Bon Jovi',
# ...

# %%
df[df["recipient"].str.contains("Manny")]
# Out:
#      year  rank       recipient      country                 career  tied  \
# 163  2015     2  Manny Pacquiao  Philippines  Sportsperson (Boxing)     0
#
#               title
# 163  Manny_Pacquiao

# %%
df[df["recipient"].str.contains("Jr")]
# Out:
#      year  rank              recipient        country                 career  \
# 158  2014     7  Floyd Mayweather, Jr.  United States  Sportsperson (Boxing)
# 161  2014    10     Robert Downey, Jr.  United States                  Actor
# 162  2015     1  Floyd Mayweather, Jr.  United States  Sportsperson (Boxing)
# 169  2015     8     Robert Downey, Jr.  United States                  Actor
# 192  2018     1  Floyd Mayweather, Jr.  United States       Athlete (Boxing)
#
#      tied                 title
# 158     0  Floyd_Mayweather_Jr.
# 161     0     Robert_Downey_Jr.
# 162     0  Floyd_Mayweather_Jr.
# 169     0     Robert_Downey_Jr.
# 192     0  Floyd_Mayweather_Jr.

# %%
# sort dataframe
df.sort_values(by="recipient")
# Out:
#      year  rank             recipient              country  \
# 78   2006     8               50 Cent        United States
# 180  2016     9                 Adele       United Kingdom
# 93   2008     3        Angelina Jolie        United States
# 102  2009     1        Angelina Jolie        United States
# 26   2001     7       Backstreet Boys        United States
# 17   2000     8       Backstreet Boys        United States
# 47   2003     7           Ben Affleck        United States
# 183  2017     2               Beyonce        United States
# 94   2008     4               Beyonce        United States
# 152  2014     1               Beyonce        United States
# 145  2013     4               Beyonce        United States
# 105  2009     4               Beyonce        United States
# 113  2010     2               Beyonce        United States
# 148  2013     7              Bon Jovi        United States
# 129  2011     8              Bon Jovi        United States
# ...

# %%
df.sort_values(by="recipient", ascending=False)
# Out:
#      year  rank             recipient              country  \
# 197  2018     6                    U2  Republic of Ireland
# 118  2010     7                    U2  Republic of Ireland
# 34   2002     5                    U2  Republic of Ireland
# 125  2011     4                    U2  Republic of Ireland
# 74   2006     4                    U2  Republic of Ireland
# 13   2000     4             Tom Hanks        United States
# 49   2003     9             Tom Hanks        United States
# 39   2002    10             Tom Hanks        United States
# 88   2007     8            Tom Cruise        United States
# 54   2004     4            Tom Cruise        United States
# 140  2012     9            Tom Cruise        United States
# 71   2006     1            Tom Cruise        United States
# 20   2001     1            Tom Cruise        United States
# 70   2005    10            Tom Cruise        United States
# 116  2010     5           Tiger Woods        United States
# ...

# %%
# filter datafram and access specific columns
df.loc[df["career"] == "Sportsperson (Boxing)", "recipient"] # this returns a pandas series
# Out:
# 158    Floyd Mayweather, Jr.
# 162    Floyd Mayweather, Jr.
# 163           Manny Pacquiao
# Name: recipient, dtype: object

# %%
df['recipient'].value_counts().index
# Out:
# Index(['Oprah Winfrey', 'Tiger Woods', 'Steven Spielberg', 'Tom Cruise',
#        'The Rolling Stones', 'Beyonce', 'Madonna', 'U2', 'Johnny Depp',
#        'Michael Jordan', 'Britney Spears', 'Cristiano Ronaldo', 'Howard Stern',
#        'Taylor Swift', 'Lady Gaga', 'Tom Hanks', 'Mel Gibson', 'Justin Bieber',
#        'James Patterson', 'LeBron James', 'J. K. Rowling', 'Katy Perry',
#        'Jay-Z', 'Elton John', 'Floyd Mayweather, Jr.', 'Brad Pitt', 'Dr. Dre',
#        'Rihanna', 'Coldplay', 'Angelina Jolie', 'Jennifer Lopez',
#        'Lionel Messi', 'Jennifer Aniston', 'Bruce Springsteen', 'George Lucas',
#        'Robert Downey, Jr.', 'One Direction', 'Ellen DeGeneres',
#        'Backstreet Boys', 'NSYNC', 'Bon Jovi', 'The Police', 'Julia Roberts',
#        'Cast of The Sopranos', 'Dwayne Johnson', 'Sean 'Diddy' Combs',
#        'Leonardo DiCaprio', 'Drake', '50 Cent', 'Celine Dion', 'Ed Sheeran',
#        'The Weeknd', 'Shaquille O'Neal', 'Kylie Jenner', 'Sandra Bullock',
# ...

# %%
# sort in descending order 
df.sort_values(by="recipient", ascending=False)
# Out:
#      year  rank             recipient              country  \
# 197  2018     6                    U2  Republic of Ireland
# 118  2010     7                    U2  Republic of Ireland
# 34   2002     5                    U2  Republic of Ireland
# 125  2011     4                    U2  Republic of Ireland
# 74   2006     4                    U2  Republic of Ireland
# 13   2000     4             Tom Hanks        United States
# 49   2003     9             Tom Hanks        United States
# 39   2002    10             Tom Hanks        United States
# 88   2007     8            Tom Cruise        United States
# 54   2004     4            Tom Cruise        United States
# 140  2012     9            Tom Cruise        United States
# 71   2006     1            Tom Cruise        United States
# 20   2001     1            Tom Cruise        United States
# 70   2005    10            Tom Cruise        United States
# 116  2010     5           Tiger Woods        United States
# ...

# %%
df.sort_values(by=["rank", "year"], ascending=[True,False])
# Out:
#      year  rank              recipient                             country  \
# 192  2018     1  Floyd Mayweather, Jr.                       United States
# 182  2017     1     Sean 'Diddy' Combs                       United States
# 172  2016     1           Taylor Swift                       United States
# 162  2015     1  Floyd Mayweather, Jr.                       United States
# 152  2014     1                Beyonce                       United States
# 142  2013     1          Oprah Winfrey                       United States
# 132  2012     1         Jennifer Lopez                       United States
# 122  2011     1              Lady Gaga                       United States
# 112  2010     1          Oprah Winfrey                       United States
# 102  2009     1         Angelina Jolie                       United States
# 91   2008     1          Oprah Winfrey                       United States
# ...

# %%
# Getting the top 5 celebrities by year

df[df["rank"]<=5].sort_values(by=["year", "rank"], ascending=[False, True])
# Out:
#      year  rank              recipient                             country  \
# 192  2018     1  Floyd Mayweather, Jr.                       United States
# 193  2018     2         George Clooney                       United States
# 194  2018     3           Kylie Jenner                       United States
# 195  2018     4         Judy Sheindlin                       United States
# 196  2018     5         Dwayne Johnson                       United States
# 182  2017     1     Sean 'Diddy' Combs                       United States
# 183  2017     2                Beyonce                       United States
# 184  2017     3          J. K. Rowling                      United Kingdom
# 185  2017     4                  Drake                              Canada
# 186  2017     5      Cristiano Ronaldo                            Portugal
# 172  2016     1           Taylor Swift                       United States
# ...

# %%
## how many times did she reach the top spot?
df_top = df.loc[(df["recipient"]=="Oprah Winfrey")  & (df["rank"]==1)]
df_top
# Out:
#      year  rank      recipient        country                  career  tied  \
# 61   2005     1  Oprah Winfrey  United States  Television Personality     0
# 81   2007     1  Oprah Winfrey  United States  Television Personality     0
# 91   2008     1  Oprah Winfrey  United States  Television Personality     0
# 112  2010     1  Oprah Winfrey  United States  Television Personality     0
# 142  2013     1  Oprah Winfrey  United States  Television Personality     0
#
#              title
# 61   Oprah_Winfrey
# 81   Oprah_Winfrey
# 91   Oprah_Winfrey
# 112  Oprah_Winfrey
# 142  Oprah_Winfrey

# %%
len(df_top)
# Out:
# 5

# %%
# Exercises 
type(df.loc)
# Out:
# pandas.core.indexing._LocIndexer

# %%
df.loc[df["career"]=="Actors", ["recipient", "year"]]
# Out:
#                recipient  year
# 79  Cast of The Sopranos  2006

# %%
# or 
df[df["career"] == "Actors"][["recipient", "year"]]
# Out:
#                recipient  year
# 79  Cast of The Sopranos  2006

# %%
df[df["country"].str.lower().str.contains("united")] # getting the countries with united
# Out:
#      year  rank              recipient                             country  \
# 0    1999     1         Michael Jordan                       United States
# 1    1999     2          Oprah Winfrey                       United States
# 2    1999     3      Leonardo DiCaprio                       United States
# 3    1999     4         Jerry Seinfeld                       United States
# 4    1999     5       Steven Spielberg                       United States
# 5    1999     6            Spice Girls                      United Kingdom
# 6    1999     7          Harrison Ford                       United States
# 7    1999     8         Robin Williams                       United States
# 9    1999    10     The Rolling Stones                      United Kingdom
# 10   2000     1          Julia Roberts                       United States
# 11   2000     2           George Lucas                       United States
# ...

# %%
df[df["country"].str.contains("united", case=False)] # getting the countries with united
# Out:
#      year  rank              recipient                             country  \
# 0    1999     1         Michael Jordan                       United States
# 1    1999     2          Oprah Winfrey                       United States
# 2    1999     3      Leonardo DiCaprio                       United States
# 3    1999     4         Jerry Seinfeld                       United States
# 4    1999     5       Steven Spielberg                       United States
# 5    1999     6            Spice Girls                      United Kingdom
# 6    1999     7          Harrison Ford                       United States
# 7    1999     8         Robin Williams                       United States
# 9    1999    10     The Rolling Stones                      United Kingdom
# 10   2000     1          Julia Roberts                       United States
# 11   2000     2           George Lucas                       United States
# ...

# %%
df[(df["rank"]>=6) & (df["rank"] % 2 != 0)]
# Out:
#      year  rank              recipient              country  \
# 6    1999     7          Harrison Ford        United States
# 8    1999     9            Celine Dion               Canada
# 16   2000     7            Tiger Woods        United States
# 18   2000     9                   Cher        United States
# 26   2001     7        Backstreet Boys        United States
# 28   2001     9          Oprah Winfrey        United States
# 36   2002     7           Mariah Carey        United States
# 38   2002     9         Michael Jordan        United States
# 47   2003     7            Ben Affleck        United States
# 49   2003     9              Tom Hanks        United States
# 57   2004     7         Michael Jordan        United States
# 59   2004     9       Steven Spielberg        United States
# 67   2005     7            Johnny Depp        United States
# 69   2005     9             Elton John       United Kingdom
# 77   2006     7           Howard Stern        United States
# ...

# %%
pd.DataFrame()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
pd.Series(pd.unique(df["country"]))
# Out:
# 0                          United States
# 1                         United Kingdom
# 2                                 Canada
# 3                    Republic of Ireland
# 4                                Various
# 5                               Barbados
# 6                            Switzerland
# 7                            Philippines
# 8     United Kingdom/Republic of Ireland
# 9                               Portugal
# 10                             Argentina
# dtype: object

# %%
type(pd.unique(df["country"]))
# Out:
# numpy.ndarray
